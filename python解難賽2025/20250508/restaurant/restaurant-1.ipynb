# %%
import pandas as pd

# %%
df = pd.read_xml("dst_restaurant.xml")
df
# Out:
#         id dish_name_zh dish_name_gb   dish_name_en   dish_name_pt  \
# 0     4004           國際           国际  International  Internacional
# 1     4005           中國           中国        Chinese        Chinesa
# 2     4006           中國           中国        Chinese        Chinesa
# 3     4008          意大利          意大利        Italian       Italiana
# 4     4010           中國           中国        Chinese        Chinesa
# ..     ...          ...          ...            ...            ...
# 584  14397         None         None           None           None
# 585  14400         None         None           None           None
# 586  14408         None         None           None           None
# 587  14411         None         None           None           None
# 588  14479         None         None           None           None
#
#          name_cn      name_gb                             name_en  \
# 0      荷里活餐廳有限公司    荷里活餐厅有限公司       HOLLYWOOD RESTAURANT, LIMITED
# ...

# %%
dish_type = df["dish_name_zh"].unique()
dish_type
# Out:
# array(['國際', '中國', '意大利', '西班牙', '葡萄牙', '葡萄牙／國際', '泰國', '火鍋', '日本', '緬甸',
#        None, '澳門／葡萄牙', '美國', '西式', '法國', '中國／國際', '宴會', '澳門／國際', '快餐',
#        '韓國', '印度'], dtype=object)

# %%
df.groupby("dish_name_zh").agg(len)["id"]
# Out:
# dish_name_zh
# 中國        186
# 中國／國際       2
# 印度          1
# 國際        123
# 宴會          6
# 快餐          2
# 意大利         9
# 日本         23
# 法國          6
# 泰國          6
# 澳門／國際       1
# 澳門／葡萄牙      4
# 火鍋          7
# 緬甸          2
# 美國          3
# 葡萄牙        37
# 葡萄牙／國際      3
# 西式          5
# 西班牙         1
# 韓國          1
# Name: id, dtype: int64

# %% [markdown]
# # Date

# %%
import datetime
today = datetime.date.today()

today.isoformat()
# Out:
# 'datetime.date(2025, 5, 8)'

# %%
print(dir(today))
# Out:
# ['__add__', '__class__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__ne__', '__new__', '__radd__', '__reduce__', '__reduce_ex__', '__repr__', '__rsub__', '__setattr__', '__sizeof__', '__str__', '__sub__', '__subclasshook__', 'ctime', 'day', 'fromisocalendar', 'fromisoformat', 'fromordinal', 'fromtimestamp', 'isocalendar', 'isoformat', 'isoweekday', 'max', 'min', 'month', 'replace', 'resolution', 'strftime', 'timetuple', 'today', 'toordinal', 'weekday', 'year']
